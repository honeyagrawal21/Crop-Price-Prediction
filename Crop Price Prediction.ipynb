# %%
#import required libraries
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/HACK_1 (1).csv")

# %%
data
# Out:
#        commodity_name          state           district        market  \
# 0               Ajwan        Gujarat             Amreli        Amreli
# 1               Ajwan        Gujarat         Banaskanth       Dhanera
# 2               Ajwan        Gujarat           Jamnagar      Jamnagar
# 3               Ajwan        Gujarat            Mehsana          Kadi
# 4               Ajwan        Gujarat            Mehsana         Unjha
# ...               ...            ...                ...           ...
# 32998     Methi+Seeds      Rajasthan               Kota          Kota
# 32999  Banana+-+Green  Uttar Pradesh       Bulandshahar  Buland Shahr
# 33000         Millets    Chattisgarh           Surajpur      Surajpur
# 33001            Lime      Rajasthan              Ajmer    Ajmer(F&V)
# 33002  Banana+-+Green  Uttar Pradesh  Gautam Budh Nagar         Dadri
#
#        min_price  max_price  modal_price        date
# 0          63.25      79.55        79.55  22-05-2019
# 1          80.05      80.05        80.05  22-05-2019
# 2          90.00     155.00       122.50  22-05-2019
# 3          94.50     112.50       107.00  22-05-2019
# 4          21.25     148.50        99.75  22-05-2019
# ...          ...        ...          ...         ...
# 32998      41.00      46.00        45.00  28-05-2019
# 32999      14.00      18.00        17.00  10-06-2019
# 33000      15.00      15.00        15.00  28-05-2019
# 33001      20.00      40.00        30.00  27-05-2019
# 33002      16.50      17.60        17.00  10-06-2019
#
# [33003 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33003 entries, 0 to 33002
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   commodity_name  33003 non-null  object
#  1   state           33003 non-null  object
#  2   district        33003 non-null  object
#  3   market          33003 non-null  object
#  4   min_price       33003 non-null  float64
#  5   max_price       33003 non-null  float64
#  6   modal_price     33003 non-null  float64
#  7   date            33003 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 2.0+ MB

# %%
data.isnull().sum()
# Out:
# commodity_name    0
# state             0
# district          0
# market            0
# min_price         0
# max_price         0
# modal_price       0
# date              0
# dtype: int64

# %%
data.head()
# Out:
#   commodity_name    state    district    market  min_price  max_price  \
# 0          Ajwan  Gujarat      Amreli    Amreli      63.25      79.55
# 1          Ajwan  Gujarat  Banaskanth   Dhanera      80.05      80.05
# 2          Ajwan  Gujarat    Jamnagar  Jamnagar      90.00     155.00
# 3          Ajwan  Gujarat     Mehsana      Kadi      94.50     112.50
# 4          Ajwan  Gujarat     Mehsana     Unjha      21.25     148.50
#
#    modal_price        date
# 0        79.55  22-05-2019
# 1        80.05  22-05-2019
# 2       122.50  22-05-2019
# 3       107.00  22-05-2019
# 4        99.75  22-05-2019

# %%
data.columns
# Out:
# Index(['commodity_name', 'state', 'district', 'market', 'min_price',
#        'max_price', 'modal_price', 'date'],
#       dtype='object')

# %%
data2=data.copy()

# %%
#replace null values with mean

# %%
data2=data2.dropna()

# %%
data2.head()
# Out:
#   commodity_name    state    district    market  min_price  max_price  \
# 0          Ajwan  Gujarat      Amreli    Amreli      63.25      79.55
# 1          Ajwan  Gujarat  Banaskanth   Dhanera      80.05      80.05
# 2          Ajwan  Gujarat    Jamnagar  Jamnagar      90.00     155.00
# 3          Ajwan  Gujarat     Mehsana      Kadi      94.50     112.50
# 4          Ajwan  Gujarat     Mehsana     Unjha      21.25     148.50
#
#    modal_price        date
# 0        79.55  22-05-2019
# 1        80.05  22-05-2019
# 2       122.50  22-05-2019
# 3       107.00  22-05-2019
# 4        99.75  22-05-2019

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33003 entries, 0 to 33002
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   commodity_name  33003 non-null  object
#  1   state           33003 non-null  object
#  2   district        33003 non-null  object
#  3   market          33003 non-null  object
#  4   min_price       33003 non-null  float64
#  5   max_price       33003 non-null  float64
#  6   modal_price     33003 non-null  float64
#  7   date            33003 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 2.0+ MB

# %%
data2.isnull().sum()
# Out:
# commodity_name    0
# state             0
# district          0
# market            0
# min_price         0
# max_price         0
# modal_price       0
# date              0
# dtype: int64

# %%
data2=data2.head(80000)

# %%
data2["date"][28]
# Out:
# '22-05-2019'

# %%
#python split method example
#variable declaration
str=data2['date'][1]
#calling function
str2=str.split("-")
#Displaying result
print(str)
print(str2)
print(str2[1])
# Out:
# 22-05-2019
# ['22', '05', '2019']
# 05

# %%
Dict={1:"January",2:"February",3:"March",4:"April",5:"May",6:"June",7:"July",8:"August",9:"September",10:"October",11:"November",12:"December"}
print(Dict)
# Out:
# {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

# %%
Dict[1]
# Out:
# 'January'

# %%
month_column=[]

# %%
#python split() method example
#variable declaration
for rr in data2["date"]:
  str=rr
  #calling function
  str2=str.split("-")
  #Displaying Result
  ##print(str)
  #print(str2)
  #print(str2[1])
  #print(Dict[int(str2[1])])
  month_column.append(Dict[int(str2[1])])

# %%
len(month_column)
# Out:
# 33003

# %%
data2["month_column"]=month_column

# %%
data2["month_column"]
# Out:
# 0         May
# 1         May
# 2         May
# 3         May
# 4         May
#          ...
# 32998     May
# 32999    June
# 33000     May
# 33001     May
# 33002    June
# Name: month_column, Length: 33003, dtype: object

# %%
data2["month_column"].unique()
# Out:
# array(['May', 'June'], dtype=object)

# %%
season_names=[]

# %%
for tt in data2["month_column"]:
  if tt =="January" or tt=="February":
    #print("Winter")
    season_names.append("Winter")
  elif tt=="March" or tt=="April":
    #print("spring")
    season_names.append("Spring")
  elif tt=="May" or tt=="June":
    #print("Summer")
    season_names.append("Summer")
  elif tt=="July" or tt=="August":
    #print("Monsoon")
    season_names.append("Monsoon")
  elif tt=="September" or tt=="October":
    #print("autumn")
    season_names.append("autumn")
  elif tt=="November" or tt=="December":
    #print("pre_Winter")
    season_names.append("pre_Winter")

# %%
data2["season_names"]=season_names

# %%
data2.head()
# Out:
#   commodity_name    state    district    market  min_price  max_price  \
# 0          Ajwan  Gujarat      Amreli    Amreli      63.25      79.55
# 1          Ajwan  Gujarat  Banaskanth   Dhanera      80.05      80.05
# 2          Ajwan  Gujarat    Jamnagar  Jamnagar      90.00     155.00
# 3          Ajwan  Gujarat     Mehsana      Kadi      94.50     112.50
# 4          Ajwan  Gujarat     Mehsana     Unjha      21.25     148.50
#
#    modal_price        date month_column season_names
# 0        79.55  22-05-2019          May       Summer
# 1        80.05  22-05-2019          May       Summer
# 2       122.50  22-05-2019          May       Summer
# 3       107.00  22-05-2019          May       Summer
# 4        99.75  22-05-2019          May       Summer

# %%
import pandas as pd
data=pd.Timestamp("2019-04-12")
print(data.dayofweek)
# Out:
# 4

# %%
day_of_week=[]

# %%
#python split method example
#variable Declaration
for rr in data2["date"]:
  str=rr
  #calling function
  df=pd.Timestamp(rr)
  day=df.dayofweek
  day_of_week.append(day)
  #str2=str.split("-")
  #Displaying result
  ##print(str)
  #print(str2)
  #print(str2[1])
  #print(Dict[int(str2[1])])
  #month_column.append(dict[int(str2[1])])

# %%
len(day_of_week)
# Out:
# 33003

# %%
data2["day"]=day_of_week

# %%
data2.tail()
# Out:
#        commodity_name          state           district        market  \
# 32998     Methi+Seeds      Rajasthan               Kota          Kota
# 32999  Banana+-+Green  Uttar Pradesh       Bulandshahar  Buland Shahr
# 33000         Millets    Chattisgarh           Surajpur      Surajpur
# 33001            Lime      Rajasthan              Ajmer    Ajmer(F&V)
# 33002  Banana+-+Green  Uttar Pradesh  Gautam Budh Nagar         Dadri
#
#        min_price  max_price  modal_price        date month_column  \
# 32998       41.0       46.0         45.0  28-05-2019          May
# 32999       14.0       18.0         17.0  10-06-2019         June
# 33000       15.0       15.0         15.0  28-05-2019          May
# 33001       20.0       40.0         30.0  27-05-2019          May
# 33002       16.5       17.6         17.0  10-06-2019         June
#
#       season_names  day
# 32998       Summer    1
# 32999       Summer    6
# 33000       Summer    1
# 33001       Summer    0
# 33002       Summer    6

# %%
data2=data2.drop('date',1)

# %%
data2.columns
# Out:
# Index(['commodity_name', 'state', 'district', 'market', 'min_price',
#        'max_price', 'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
data2=data2.head(83000)

# %%
#box plot
import seaborn as sns
sns.boxplot(x=data2['modal_price'])
# Out:
# <Axes: xlabel='modal_price'>

# %%
data2.shape
# Out:
# (33003, 10)

# %%
data2['modal_price']
# Out:
# 0         79.55
# 1         80.05
# 2        122.50
# 3        107.00
# 4         99.75
#           ...
# 32998     45.00
# 32999     17.00
# 33000     15.00
# 33001     30.00
# 33002     17.00
# Name: modal_price, Length: 33003, dtype: float64

# %%
def detect_outliers(data2,features):
    outlier_indices = []
    for col in features:
        Q1 = np.percentile(data2[col], 25)
        Q3 = np.percentile(data2[col],75)
        IQR = Q3 - Q1
        outlier_step = 1.5 * IQR
        outlier_list_col = data2[(data2[col] < Q1 - outlier_step) | (data2[col] > Q3 + outlier_step )].index
        outlier_indices.extend(outlier_list_col)  

    return outlier_indices

# %%
len(detect_outliers(data2,["modal_price"]))
# Out:
# 1668

# %%
#IQR
Q1=np.percentile(data2["modal_price"],25,interpolation="midpoint")
Q3=np.percentile(data2["modal_price"],75,interpolation="midpoint")
IQR=Q3-Q1

# %%
upper=np.where(data2["modal_price"]>=(Q3+1.5*IQR))
lower=np.where(data2["modal_price"]<=(Q1-1.5*IQR))

# %%
print(upper[0],lower[0])
# Out:
# [    0     1     2 ... 32924 32968 32996] []

# %%
'''Removing the outliers'''
data2.drop(upper[0],inplace=True)
data2.drop(lower[0],inplace=True)

# %%
print("New Shape:",data2.shape)
# Out:
# New Shape: (31335, 10)

# %%
data=data2.copy()

# %%
data2.columns
# Out:
# Index(['commodity_name', 'state', 'district', 'market', 'min_price',
#        'max_price', 'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
import seaborn as sns
sns.boxplot(x=data2['modal_price'])
# Out:
# <Axes: xlabel='modal_price'>

# %%
import plotly.express as px

# %%
sns.relplot(data=data,x="state",y="modal_price",hue="season_names",kind="line")

# %%
sns.relplot(data=data,x="district",y="modal_price",hue="season_names",kind="line")

# %%
fig=px.bar(data,x="district",y="modal_price",color="season_names",height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="33ac5707-c6be-40c8-b99a-01c820121082" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33ac5707-c6be-40c8-b99a-01c820121082")) {                    Plotly.newPlot(                        "33ac5707-c6be-40c8-b99a-01c820121082",                        [{"alignmentgroup":"True","hovertemplate":"season_names=Summer<br>district=%{x}<br>modal_price=%{y}<extra></extra>","legendgroup":"Summer","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Summer","offsetgroup":"Summer","orientation":"v","showlegend":true,"textposition":"auto","x":["Chittorgarh","Bagalkot","Bangalore","Gadag","Panna","Ernakulam","Kollam","Ernakulam","Thiruvananthapuram","Thiruvananthapuram","Thirssur","Alappuzha","Alappuzha","Kozhikode(Calicut)","Kasargod","Alappuzha","Palakad","Malappuram","Ernakulam","Malappuram","Pathanamthitta","Alappuzha","Malappuram","Kasargod","Kozhikode(Calicut)","Kasargod","Thiruvananthapuram","Palakad","Kozhikode(Calicut)","Kottayam","Palakad","Kannur","Kozhikode(Calicut)","Ernakulam","Thiruvananthapuram","Wayanad","Kozhikode(Calicut)","Kottayam","Idukki","Thirssur","Palakad","Kozhikode(Calicut)","Palakad","Malappuram","Malappuram","Sangrur","Kanpur","Alappuzha","Ernakulam","Thiruvananthapuram","Alappuzha","Alappuzha","Kozhikode(Calicut)","Alappuzha","Malappuram","Alappuzha","Alappuzha","Kozhikode(Calicut)","Kasargod","Thiruvananthapuram","Kozhikode(Calicut)","Malappuram","Thiruvananthapuram","Kozhikode(Calicut)","Idukki","Ernakulam","Chikmagalur","Durg","Karnal","Jind","Kurukshetra","Sirmore","Solan","Malappuram","Harda","Pune","Delhi","Sangrur","Hoshiarpur","Tarntaran","Ajmer","Ganganagar","Udaipur","Agra","Aligarh","Maharajganj","Banda","Auraiya","Azamgarh","Badaun","Ballia","Unnao","Baghpat","Bareilly","Basti","Mainpuri","Etawah","Bijnor","Bulandshahar","Muradabad","Aligarh","Etah","Etawah","Agra","Saharanpur","Ghaziabad","Mainpuri","Gonda","Gorakhpur","Jyotiba Phule Nagar","Bulandshahar","Jalaun (Orai)","Agra","Jaunpur","Jhansi","Kanpur","Kannuj","Kanpur","Chitrakut","Etah","Agra","Bulandshahar","Mau(Maunathbhanjan)","Mathura","Lalitpur","Lucknow","Hardoi","Maharajganj","Mahoba","Mainpuri","Mau(Maunathbhanjan)","Jhansi","Meerut","Meerut","Mirzapur","Muradabad","Muzaffarnagar","Siddharth Nagar","Jalaun (Orai)","Pillibhit","Kanpur","Pillibhit","Rampur","Bahraich","Saharanpur","Siddharth Nagar","Muradabad","Agra","Jaunpur","Shahjahanpur","Firozabad","Sitapur","Sultanpur","Padrauna(Kusinagar)","Firozabad","Haridwar","UdhamSinghNagar","Garhwal (Pauri)","Haridwar","Dehradoon","Kolkata","Nalbari","Sagar","Buldhana","Mumbai","Agra","Allahabad","Azamgarh","Balrampur","Bareilly","Basti","Etawah","Aligarh","Kannuj","Gorakhpur","Kanpur","Mau(Maunathbhanjan)","Etah","Etawah","Farukhabad","Ghaziabad","Gorakhpur","Hathras","Bulandshahar","Etah","Farukhabad","Bulandshahar","Mau(Maunathbhanjan)","Mathura","Lucknow","Maharajganj","Mainpuri","Meerut","Mirzapur","Hamirpur","Lakhimpur","Kanpur","Pillibhit","Saharanpur","Gorakhpur","Hardoi","Sitapur","Padrauna(Kusinagar)","Unnao","Varanasi","Puruliya","Birbhum","Kollam","Ernakulam","Alappuzha","Kottayam","Thiruvananthapuram","Thirssur","Thirssur","Alappuzha","Alappuzha","Kottayam","Alappuzha","Kozhikode(Calicut)","Wayanad","Kasargod","Alappuzha","Palakad","Malappuram","Ernakulam","Malappuram","Pathanamthitta","Alappuzha","Malappuram","Kasargod","Alappuzha","Kozhikode(Calicut)","Palakad","Kozhikode(Calicut)","Kottayam","Palakad","Kannur","Ernakulam","Kozhikode(Calicut)","Kottayam","Idukki","Ernakulam","Thirssur","Palakad","Palakad","Kozhikode(Calicut)","Bangalore","Rajnandgaon","Narmada","Karnal","Hissar","Bhiwani","Kaithal","Kaithal","Fatehabad","Sonipat","Kurukshetra","Sirsa","Rohtak","Mahendragarh-Narn ...

# %%
sns.relplot(data=data,x="season_names",y="modal_price",hue="season_names",kind="line")

# %%
sns.relplot(data=data,x="day",y="modal_price",hue="season_names",kind="line")

# %%
data2.columns
# Out:
# Index(['commodity_name', 'state', 'district', 'market', 'min_price',
#        'max_price', 'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
sns.relplot(data=data,x="market",y="modal_price",hue="season_names",kind="line")

# %%
sns.relplot(data=data,x="month_column",y="modal_price",hue="season_names",kind="line")

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31335 entries, 6 to 33002
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   commodity_name  31335 non-null  object
#  1   state           31335 non-null  object
#  2   district        31335 non-null  object
#  3   market          31335 non-null  object
#  4   min_price       31335 non-null  float64
#  5   max_price       31335 non-null  float64
#  6   modal_price     31335 non-null  float64
#  7   month_column    31335 non-null  object
#  8   season_names    31335 non-null  object
#  9   day             31335 non-null  int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.6+ MB

# %%
dist=(data2['commodity_name'])
distset=set(dist)
dd=list(distset)
dictOfWords={dd[i]:i for i in range(0,len(dd) )}
data2['commodity_name']=data2['commodity_name'].map(dictOfWords)

# %%
dist=(data2['state'])
distset=set(dist)
dd=list(distset)
dictOfWords={dd[i]:i for i in range(0,len(dd) )}
data2['state']=data2['state'].map(dictOfWords)

# %%
dist=(data2['district'])
distset=set(dist)
dd=list(distset)
dictOfWords={dd[i]:i for i in range(0,len(dd) )}
data2['district']=data2['district'].map(dictOfWords)

# %%
dist=(data2['market'])
distset=set(dist)
dd=list(distset)
dictOfWords={dd[i]:i for i in range(0,len(dd) )}
data2['market']=data2['market'].map(dictOfWords)

# %%
dist=(data2['month_column'])
distset=set(dist)
dd=list(distset)
dictOfWords={dd[i]:i for i in range(0,len(dd) )}
data2['month_column']=data2['month_column'].map(dictOfWords)

# %%
dist=(data2['season_names'])
distset=set(dist)
dd=list(distset)
dictOfWords={dd[i]:i for i in range(0,len(dd) )}
data2['season_names']=data2['season_names'].map(dictOfWords)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31335 entries, 6 to 33002
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   commodity_name  31335 non-null  int64
#  1   state           31335 non-null  int64
#  2   district        31335 non-null  int64
#  3   market          31335 non-null  int64
#  4   min_price       31335 non-null  float64
#  5   max_price       31335 non-null  float64
#  6   modal_price     31335 non-null  float64
#  7   month_column    31335 non-null  int64
#  8   season_names    31335 non-null  int64
#  9   day             31335 non-null  int64
# dtypes: float64(3), int64(7)
# memory usage: 3.6 MB

# %%
import matplotlib.pyplot as plt

# %%
#print(data2.corr())
#plotting  correlation heatmap
dataplot =sns.heatmap(data2.corr(),cmap="YlGnBu",annot=True)
#displaying heatmap
plt.show()

# %%
#train and test split data
#training multiple Models

# %%
data2.columns
# Out:
# Index(['commodity_name', 'state', 'district', 'market', 'min_price',
#        'max_price', 'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
features=data2[['commodity_name','state','district','market','month_column','season_names','day']]
label=data2['modal_price']

# %%
#splitting into train and test data

from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(features,label,test_size=0.2,random_state=2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
regr=RandomForestRegressor(max_depth=1000,random_state=0)
regr.fit(Xtrain,Ytrain)
#print(regr.predict(Ytest[0]))
# Out:
# RandomForestRegressor(max_depth=1000, random_state=0)

# %%
Xtest[0:1]
# Out:
#        commodity_name  state  district  market  month_column  season_names  \
# 21221             110      7       355    1432             1             0
#
#        day
# 21221    6

# %%
y_pred=regr.predict(Xtest)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Ytest,y_pred)
# Out:
# 0.8913195413709165

# %%
y_pred
# Out:
# array([10.237     , 23.6075    ,  2.45666667, ..., 46.3985    ,
#        13.13991667, 30.7515    ])

# %%
data2.columns
# Out:
# Index(['commodity_name', 'state', 'district', 'market', 'min_price',
#        'max_price', 'modal_price', 'month_column', 'season_names', 'day'],
#       dtype='object')

# %%
Xtest[0:1]
# Out:
#        commodity_name  state  district  market  month_column  season_names  \
# 21221             110      7       355    1432             1             0
#
#        day
# 21221    6

# %%
user=input("Enter input:").split()
user=[int(i) for i in user]
result=float(regr.predict([user]))
print(result)
# Out:
# Enter input:1 2 3 4 5 6 7
# 43.951
